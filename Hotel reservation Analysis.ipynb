# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.style.use('ggplot')

# %%
data_path = r'C:\Users\moham\Desktop\ \Bi Work\My Work\Data analysis with python\Project 3_ Hotel Reservation Analysis\Hotel_Reservation_Analysis\Hotel Reservations.csv'
hotl_data = pd.read_csv(data_path)

# %%
hotl_data
# Out:
#       Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0       INN00001             2               0                     1
# 1       INN00002             2               0                     2
# 2       INN00003             1               0                     2
# 3       INN00004             2               0                     0
# 4       INN00005             2               0                     1
# ...          ...           ...             ...                   ...
# 36270   INN36271             3               0                     2
# 36271   INN36272             2               0                     1
# 36272   INN36273             2               0                     2
# 36273   INN36274             2               0                     0
# 36274   INN36275             2               0                     1
#
#        no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# ...

# %%
# display the shape of data 
hotl_data.shape
# Out:
# (36275, 19)

# %%
# see all columns 
hotl_data.columns
# Out:
# Index(['Booking_ID', 'no_of_adults', 'no_of_children', 'no_of_weekend_nights',
#        'no_of_week_nights', 'type_of_meal_plan', 'required_car_parking_space',
#        'room_type_reserved', 'lead_time', 'arrival_year', 'arrival_month',
#        'arrival_date', 'market_segment_type', 'repeated_guest',
#        'no_of_previous_cancellations', 'no_of_previous_bookings_not_canceled',
#        'avg_price_per_room', 'no_of_special_requests', 'booking_status'],
#       dtype='object')

# %%
# seeing all columns datatypes to see if any chnage needed to be done in data 
hotl_data.dtypes
# Out:
# Booking_ID                               object
# no_of_adults                              int64
# no_of_children                            int64
# no_of_weekend_nights                      int64
# no_of_week_nights                         int64
# type_of_meal_plan                        object
# required_car_parking_space                int64
# room_type_reserved                       object
# lead_time                                 int64
# arrival_year                              int64
# arrival_month                             int64
# arrival_date                              int64
# market_segment_type                      object
# repeated_guest                            int64
# no_of_previous_cancellations              int64
# no_of_previous_bookings_not_canceled      int64
# avg_price_per_room                      float64
# no_of_special_requests                    int64
# booking_status                           object
# dtype: object

# %%
# numbers of nulls in each column 
hotl_data.isna().sum()
# Out:
# Booking_ID                              0
# no_of_adults                            0
# no_of_children                          0
# no_of_weekend_nights                    0
# no_of_week_nights                       0
# type_of_meal_plan                       0
# required_car_parking_space              0
# room_type_reserved                      0
# lead_time                               0
# arrival_year                            0
# arrival_month                           0
# arrival_date                            0
# market_segment_type                     0
# repeated_guest                          0
# no_of_previous_cancellations            0
# no_of_previous_bookings_not_canceled    0
# avg_price_per_room                      0
# no_of_special_requests                  0
# booking_status                          0
# dtype: int64

# %%
## it looks like my data is very cleaned 
## lets see more information about my data 
hotl_data.describe()
# Out:
#        no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# count  36275.000000    36275.000000          36275.000000       36275.000000
# mean       1.844962        0.105279              0.810724           2.204300
# std        0.518715        0.402648              0.870644           1.410905
# min        0.000000        0.000000              0.000000           0.000000
# 25%        2.000000        0.000000              0.000000           1.000000
# 50%        2.000000        0.000000              1.000000           2.000000
# 75%        2.000000        0.000000              2.000000           3.000000
# max        4.000000       10.000000              7.000000          17.000000
#
#        required_car_parking_space     lead_time  arrival_year  arrival_month  \
# count                36275.000000  36275.000000  36275.000000   36275.000000
# mean                     0.030986     85.232557   2017.820427       7.423653
# ...

# %%
# now its time to see the distripution of the distinct values of a specific columns to know more about it 
hotl_data['no_of_adults'].value_counts()
# Out:
# 2    26108
# 1     7695
# 3     2317
# 0      139
# 4       16
# Name: no_of_adults, dtype: int64

# %% [markdown]
#  it looks like most of reservations are couples reservatoins
#     and the least partition of it to the family reservations or group of reservatoins

# %%
hotl_data['no_of_children'].value_counts()
# Out:
# 0     33577
# 1      1618
# 2      1058
# 3        19
# 9         2
# 10        1
# Name: no_of_children, dtype: int64

# %% [markdown]
# also now it is clear that most of the reservations are couples reservations

# %%
hotl_data['no_of_weekend_nights'].value_counts()
# Out:
# 0    16872
# 1     9995
# 2     9071
# 3      153
# 4      129
# 5       34
# 6       20
# 7        1
# Name: no_of_weekend_nights, dtype: int64

# %%
hotl_data['no_of_week_nights'].value_counts()
# Out:
# 2     11444
# 1      9488
# 3      7839
# 4      2990
# 0      2387
# 5      1614
# 6       189
# 7       113
# 10       62
# 8        62
# 9        34
# 11       17
# 15       10
# 12        9
# 14        7
# 13        5
# 17        3
# 16        2
# Name: no_of_week_nights, dtype: int64

# %%
hotl_data['required_car_parking_space'].value_counts()
# Out:
# 0    35151
# 1     1124
# Name: required_car_parking_space, dtype: int64

# %% [markdown]
# now its clear that most of reservations owners are not have cars

# %%
hotl_data['lead_time'].plot(kind ='hist',bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# it seems like most of the reservatios are reserved with a small persiod of notice

# %%
hotl_data
# Out:
#       Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0       INN00001             2               0                     1
# 1       INN00002             2               0                     2
# 2       INN00003             1               0                     2
# 3       INN00004             2               0                     0
# 4       INN00005             2               0                     1
# ...          ...           ...             ...                   ...
# 36270   INN36271             3               0                     2
# 36271   INN36272             2               0                     1
# 36272   INN36273             2               0                     2
# 36273   INN36274             2               0                     0
# 36274   INN36275             2               0                     1
#
#        no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# ...

# %%
hotl_data.groupby('room_type_reserved')['Booking_ID'].count()
# Out:
# room_type_reserved
# Room_Type 1    28130
# Room_Type 2      692
# Room_Type 3        7
# Room_Type 4     6057
# Room_Type 5      265
# Room_Type 6      966
# Room_Type 7      158
# Name: Booking_ID, dtype: int64

# %%
hotl_data.groupby('room_type_reserved')['Booking_ID'].count().plot(kind='pie')
# Out:
# <Axes: ylabel='Booking_ID'>

# %%
hotl_data.market_segment_type.value_counts()
# Out:
# Online           23214
# Offline          10528
# Corporate         2017
# Complementary      391
# Aviation           125
# Name: market_segment_type, dtype: int64

# %%
hotl_data['booking_status'].value_counts()
# Out:
# Not_Canceled    24390
# Canceled        11885
# Name: booking_status, dtype: int64

# %%
# seeing if it is related to market segment type to the cacelation of the reservation 
hotl_data.query('booking_status == "Canceled"')['market_segment_type'].value_counts()
# Out:
# Online       8475
# Offline      3153
# Corporate     220
# Aviation       37
# Name: market_segment_type, dtype: int64

# %% [markdown]
# here i can see that it isnot occure that any reservation of complementary reservations is canceled and its is a good insight

# %%
hotl_data['market_segment_type'].value_counts().plot(kind='barh')
# Out:
# <Axes: >

# %%
hotl_data.query('market_segment_type == "Online"')['booking_status'].value_counts().plot(kind='pie')

plt.show()

# %%
hotl_data.query('market_segment_type == "Offline"')['booking_status'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='booking_status'>

# %%
hotl_data.query('market_segment_type == "Corporate"')['booking_status'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='booking_status'>

# %%
hotl_data.query('market_segment_type == "Aviation"')['booking_status'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='booking_status'>

# %%
hotl_data.query('market_segment_type == "Complementary"')['booking_status'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='booking_status'>

# %%
hotl_data
# Out:
#       Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0       INN00001             2               0                     1
# 1       INN00002             2               0                     2
# 2       INN00003             1               0                     2
# 3       INN00004             2               0                     0
# 4       INN00005             2               0                     1
# ...          ...           ...             ...                   ...
# 36270   INN36271             3               0                     2
# 36271   INN36272             2               0                     1
# 36272   INN36273             2               0                     2
# 36273   INN36274             2               0                     0
# 36274   INN36275             2               0                     1
#
#        no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# ...

# %%
hotl_data['no_of_previous_cancellations'].value_counts()
# Out:
# 0     35937
# 1       198
# 2        46
# 3        43
# 11       25
# 5        11
# 4        10
# 13        4
# 6         1
# Name: no_of_previous_cancellations, dtype: int64

# %%
hotl_data.query('booking_status == "Canceled"')['no_of_previous_cancellations'].value_counts()
# Out:
# 0     11869
# 1        11
# 13        4
# 3         1
# Name: no_of_previous_cancellations, dtype: int64

# %%
hotl_data.query('booking_status == "Not_Canceled"')['no_of_previous_cancellations'].value_counts()
# Out:
# 0     24068
# 1       187
# 2        46
# 3        42
# 11       25
# 5        11
# 4        10
# 6         1
# Name: no_of_previous_cancellations, dtype: int64

# %% [markdown]
# here we can chose and action to not accept any reserv with more than 11 reserv cancelation casuse of it oftens canceled aslo

# %%
sns.scatterplot(x='no_of_adults' , y='no_of_children' ,hue='booking_status',data=hotl_data)
# Out:
# <Axes: xlabel='no_of_adults', ylabel='no_of_children'>

# %% [markdown]
# ## See Correlation of the data

# %% [markdown]
# now i should chose the numeric columns to see the correlation between all data

# %%
hotl_data[['no_of_adults','no_of_children','no_of_weekend_nights','no_of_week_nights','repeated_guest','no_of_previous_cancellations','no_of_previous_bookings_not_canceled','avg_price_per_room']].corr()
# Out:
#                                       no_of_adults  no_of_children  \
# no_of_adults                              1.000000       -0.019787
# no_of_children                           -0.019787        1.000000
# no_of_weekend_nights                      0.103316        0.029478
# no_of_week_nights                         0.105622        0.024398
# repeated_guest                           -0.192277       -0.036348
# no_of_previous_cancellations             -0.047426       -0.016390
# no_of_previous_bookings_not_canceled     -0.119166       -0.021189
# avg_price_per_room                        0.296886        0.337728
#
#                                       no_of_weekend_nights  no_of_week_nights  \
# no_of_adults                                      0.103316           0.105622
# no_of_children                                    0.029478           0.024398
# no_of_weekend_nights                              1.000000           0.179577
# ...

# %%
hotl_data
# Out:
#       Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0       INN00001             2               0                     1
# 1       INN00002             2               0                     2
# 2       INN00003             1               0                     2
# 3       INN00004             2               0                     0
# 4       INN00005             2               0                     1
# ...          ...           ...             ...                   ...
# 36270   INN36271             3               0                     2
# 36271   INN36272             2               0                     1
# 36272   INN36273             2               0                     2
# 36273   INN36274             2               0                     0
# 36274   INN36275             2               0                     1
#
#        no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# ...

# %%
hotl_data.insert(19 , 'Booking Status_bool' , np.where(hotl_data['booking_status'] =='Not_Canceled' , 1,0) )

# %%
hotl_data
# Out:
#       Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0       INN00001             2               0                     1
# 1       INN00002             2               0                     2
# 2       INN00003             1               0                     2
# 3       INN00004             2               0                     0
# 4       INN00005             2               0                     1
# ...          ...           ...             ...                   ...
# 36270   INN36271             3               0                     2
# 36271   INN36272             2               0                     1
# 36272   INN36273             2               0                     2
# 36273   INN36274             2               0                     0
# 36274   INN36275             2               0                     1
#
#        no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# ...

# %%
hotl_data[['no_of_adults','no_of_children','no_of_weekend_nights','no_of_week_nights','repeated_guest','no_of_previous_cancellations','no_of_previous_bookings_not_canceled','avg_price_per_room' , 'Booking Status_bool']].corr()
# Out:
#                                       no_of_adults  no_of_children  \
# no_of_adults                              1.000000       -0.019787
# no_of_children                           -0.019787        1.000000
# no_of_weekend_nights                      0.103316        0.029478
# no_of_week_nights                         0.105622        0.024398
# repeated_guest                           -0.192277       -0.036348
# no_of_previous_cancellations             -0.047426       -0.016390
# no_of_previous_bookings_not_canceled     -0.119166       -0.021189
# avg_price_per_room                        0.296886        0.337728
# Booking Status_bool                      -0.086920       -0.033078
#
#                                       no_of_weekend_nights  no_of_week_nights  \
# no_of_adults                                      0.103316           0.105622
# no_of_children                                    0.029478           0.024398
# ...

# %% [markdown]
# make it as heatmap

# %%
tbl_corr = hotl_data[['no_of_adults','no_of_children','no_of_weekend_nights','no_of_week_nights','repeated_guest','no_of_previous_cancellations','no_of_previous_bookings_not_canceled','avg_price_per_room' , 'Booking Status_bool']].corr()
sns.heatmap(data=tbl_corr , annot=True)
# Out:
# <Axes: >
